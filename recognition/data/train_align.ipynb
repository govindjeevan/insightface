# %%
data_path = "/storage/MysterioNet/datasets/smdf/original/lfw_masked"
dest_path = "/storage/MysterioNet/datasets/smdf/original/lfw-masked-retina"

# %%
# !mkdir $dest_path

# %%
# !python3 train_align.py --data-dir $data_path --dest-dir $dest_path  --det-prefix ../../RetinaFace/model/R50 --ext jpg
# Out:
# [32, 16, 8] {'32': {'SCALES': (32, 16), 'BASE_SIZE': 16, 'RATIOS': (1.0,), 'ALLOWED_BORDER': 9999}, '16': {'SCALES': (8, 4), 'BASE_SIZE': 16, 'RATIOS': (1.0,), 'ALLOWED_BORDER': 9999}, '8': {'SCALES': (2, 1), 'BASE_SIZE': 16, 'RATIOS': (1.0,), 'ALLOWED_BORDER': 9999}}
# [08:04:08] src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v1.3.0. Attempting to upgrade...
# [08:04:08] src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# means [0. 0. 0.]
# use_landmarks True
# cascade 0
# sym size: 9
# Miguel_Hakim
# Ross_Verba
# Wolfgang_Schuessel
# Joan_Dangerfield
# Patsy_Kensit
# Norman_Jewison
# Laura_Gobai
# Mike_Gable
# Arturo_Gatti
# Colin_Cowie
# Pernilla_Bjorn
# Monique_Ferreira
# Pete_Aldridge
# Sebastian_Cuattrin
# Wilbert_Foy
# David_Sibleyk
# Victoria_Clarke
# Jim_Piper
# Gil_Cates
# Mireya_Moscoso
# Nuon_Chea
# David_Brown
# Ben_Broussard
# Todd_Parrott
# Jose_Luis_Chilavert
# James_Coburn
# Harold_Scott
# Patrick_Clawsen
# Elinor_Caplan
# ...
